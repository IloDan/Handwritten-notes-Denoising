# %% [markdown]
# ### Import Dependencies

# %%
from PIL import Image
from tabulate import tabulate

from rmac import SearchEngine
from utils import show_query_img, show_top_matches
from evaluation import compute_mAP

# %% [markdown]
# ### Open Query Image

# %%
# Open image 
query_path = "db_2/data/img_98.png"

# Show query image
show_query_img(img_path=query_path)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with VGG16 Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='vgg16', max_scale_level=6)
# Out:
# 2023-10-02 12:39:27 - INFO: Database path is: db_2
# 2023-10-02 12:39:28 - INFO: Number of images in the database: 200
# 2023-10-02 12:39:28 - INFO: Using device: cpu
# 2023-10-02 12:39:37 - INFO: Backbone model is: vgg16
# 2023-10-02 12:39:37 - INFO: Min scale level is: 1
# 2023-10-02 12:39:37 - INFO: Max scale level is: 6
# 2023-10-02 12:39:37 - INFO: Loading database feature matrix...

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=20)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))
# Out:
# 2023-10-02 12:39:45 - INFO: Computing top-k matches...
# Top matches for query db_2/data/img_98.png:
# Path                      Score
# ---------------------  --------
# db_2/data/img_93.png   1
# db_2/data/img_118.png  0.988891
# db_2/data/img_172.png  0.98879
# db_2/data/img_32.png   0.98869
# db_2/data/img_81.png   0.98869
# db_2/data/img_36.png   0.987551
# db_2/data/img_22.png   0.987536
# db_2/data/img_7.png    0.984965
# db_2/data/img_121.png  0.975474
# db_2/data/img_38.png   0.974376
# db_2/data/img_124.png  0.973771
# db_2/data/img_150.png  0.971614
# db_2/data/img_192.png  0.961965
# db_2/data/img_72.png   0.960102
# db_2/data/img_110.png  0.958761
# db_2/data/img_111.png  0.955536
# db_2/data/img_196.png  0.951806
# db_2/data/img_132.png  0.950082
# db_2/data/img_195.png  0.946232
# db_2/data/img_119.png  0.945358

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with VGG19 Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='vgg19', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=10)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with DenseNet Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='densenet', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=10)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with Trained UNet Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='trained_unet', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('L')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=10)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with Kaiming '0' UNet Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='kaiming_unet_0', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=20)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with Kaiming '1' UNet Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='kaiming_unet_1', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=20)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)

# %% [markdown]
# ---

# %% [markdown]
# ### Instantiate Search Engine Object with Kaiming '2' UNet Backbone

# %%
img_ret = SearchEngine(db_path='db_2/data', backbone='kaiming_unet_2', max_scale_level=6)

# %% [markdown]
# ### Retrieve Similar Images

# %%
# Compute top matches
img = Image.open(query_path).convert('RGB')
img = img_ret.transform(img).to(img_ret.device)
results = img_ret.compute_top_matches(img, top_k=20)

table = [(path, score) for path, score in results]

print(f"Top matches for query {query_path}:")
print(tabulate(table, headers=['Path', 'Score'], tablefmt="rounded_grid"))

# %%
show_top_matches(results)

# %% [markdown]
# ### Evaluate mAP

# %%
k_thresholds = [3, 5, 10, 20]
table_data = []

for k in k_thresholds:
    mAP = compute_mAP(img_ret, top_k_threshold=k)  
    table_data.append([k, mAP])

table_headers = ["k_threshold", "mAP"]

table = tabulate(table_data, headers=table_headers, tablefmt="rounded_grid")

print(table)
